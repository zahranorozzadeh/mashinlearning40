# %% [markdown]
# <a href="https://colab.research.google.com/github/zahranorozzadeh/mashinlearning40/blob/main/House_Pricing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install wandb
import wandb
from wandb.keras import WandbCallback
# Out:
# Collecting wandb
#   Downloading wandb-0.12.1-py2.py3-none-any.whl (1.7 MB)
#      |████████████████████████████████| 1.7 MB 3.2 MB/s
# Requirement already satisfied: six>=1.13.0 in /usr/local/lib/python3.7/dist-packages (from wandb) (1.15.0)
# Collecting shortuuid>=0.5.0
#   Downloading shortuuid-1.0.1-py3-none-any.whl (7.5 kB)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.7/dist-packages (from wandb) (3.13)
# Requirement already satisfied: promise<3,>=2.0 in /usr/local/lib/python3.7/dist-packages (from wandb) (2.3)
# Collecting GitPython>=1.0.0
#   Downloading GitPython-3.1.18-py3-none-any.whl (170 kB)
#      |████████████████████████████████| 170 kB 58.5 MB/s
# Collecting subprocess32>=3.5.3
#   Downloading subprocess32-3.5.4.tar.gz (97 kB)
#      |████████████████████████████████| 97 kB 6.7 MB/s
# Requirement already satisfied: requests<3,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from wandb) (2.23.0)
# Collecting sentry-sdk>=1.0.0
#   Downloading sentry_sdk-1.3.1-py2.py3-none-any.whl (133 kB)
#      |████████████████████████████████| 133 kB 47.5 MB/s
# Requirement already satisfied: protobuf>=3.12.0 in /usr/local/lib/python3.7/dist-packages (from wandb) (3.17.3)
# Requirement already satisfied: python-dateutil>=2.6.1 in /usr/local/lib/python3.7/dist-packages (from wandb) (2.8.2)
# Requirement already satisfied: psutil>=5.0.0 in /usr/local/lib/python3.7/dist-packages (from wandb) (5.4.8)
# Collecting docker-pycreds>=0.4.0
#   Downloading docker_pycreds-0.4.0-py2.py3-none-any.whl (9.0 kB)
# Collecting pathtools
#   Downloading pathtools-0.1.2.tar.gz (11 kB)
# Collecting configparser>=3.8.1
#   Downloading configparser-5.0.2-py3-none-any.whl (19 kB)
# Requirement already satisfied: Click!=8.0.0,>=7.0 in /usr/local/lib/python3.7/dist-packages (from wandb) (7.1.2)
# Requirement already satisfied: typing-extensions>=3.7.4.0 in /usr/local/lib/python3.7/dist-packages (from GitPython>=1.0.0->wandb) (3.7.4.3)
# Collecting gitdb<5,>=4.0.1
#   Downloading gitdb-4.0.7-py3-none-any.whl (63 kB)
#      |████████████████████████████████| 63 kB 1.7 MB/s
# Collecting smmap<5,>=3.0.1
#   Downloading smmap-4.0.0-py2.py3-none-any.whl (24 kB)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.0.0->wandb) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.0.0->wandb) (2021.5.30)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.0.0->wandb) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.0.0->wandb) (3.0.4)
# Building wheels for collected packages: subprocess32, pathtools
#   Building wheel for subprocess32 (setup.py) ... done
#   Created wheel for subprocess32: filename=subprocess32-3.5.4-py3-none-any.whl size=6502 sha256=c356ef35e2fde696d5e13793ddf4f23a1ce1c70599be9b936a4980d932762efb
#   Stored in directory: /root/.cache/pip/wheels/50/ca/fa/8fca8d246e64f19488d07567547ddec8eb084e8c0d7a59226a
#   Building wheel for pathtools (setup.py) ... done
#   Created wheel for pathtools: filename=pathtools-0.1.2-py3-none-any.whl size=8807 sha256=bdf70e9ec65a3286ac4d09e44e5830b2ae29f91618f4936346020e6918c57f8b
#   Stored in directory: /root/.cache/pip/wheels/3e/31/09/fa59cef12cdcfecc627b3d24273699f390e71828921b2cbba2
# Successfully built subprocess32 pathtools
# Installing collected packages: smmap, gitdb, subprocess32, shortuuid, sentry-sdk, pathtools, GitPython, docker-pycreds, configparser, wandb
# Successfully installed GitPython-3.1.18 configparser-5.0.2 docker-pycreds-0.4.0 gitdb-4.0.7 pathtools-0.1.2 sentry-sdk-1.3.1 shortuuid-1.0.1 smmap-4.0.0 subprocess32-3.5.4 wandb-0.12.1

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf
import wandb
from wandb.keras import WandbCallback
from sklearn.model_selection import train_test_split

# %%
wandb.init(project='Kaggle House Prices Using MLP', entity='zahra-norozzadeh')
# Out:
# Finishing last run (ID:2f4xgc9z) before initializing another...
# <br/>Waiting for W&B process to finish, PID 426<br/>Program ended successfully.
# VBox(children=(Label(value=' 0.00MB of 0.00MB uploaded (0.00MB deduped)\r'), FloatProgress(value=1.0, max=1.0)…
# Find user logs for this run at: <code>/content/wandb/run-20210904_230048-2f4xgc9z/logs/debug.log</code>
# Find internal logs for this run at: <code>/content/wandb/run-20210904_230048-2f4xgc9z/logs/debug-internal.log</code>
# Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
#                     <br/>Synced <strong style="color:#cdcd00">fresh-serenity-3</strong>: <a href="https://wandb.ai/zahra-norozzadeh/Kaggle%20House%20Prices%20Using%20MLP/runs/2f4xgc9z" target="_blank">https://wandb.ai/zahra-norozzadeh/Kaggle%20House%20Prices%20Using%20MLP/runs/2f4xgc9z</a><br/>
# ...Successfully finished last run (ID:2f4xgc9z). Initializing new run:<br/><br/>
#                 Tracking run with wandb version 0.12.1<br/>
#                 Syncing run <strong style="color:#cdcd00">vocal-dew-4</strong> to <a href="https://wandb.ai" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://wandb.ai/zahra-norozzadeh/Kaggle%20House%20Prices%20Using%20MLP" target="_blank">https://wandb.ai/zahra-norozzadeh/Kaggle%20House%20Prices%20Using%20MLP</a><br/>
#                 Run page: <a href="https://wandb.ai/zahra-norozzadeh/Kaggle%20House%20Prices%20Using%20MLP/runs/26uwvn4y" target="_blank">https://wandb.ai/zahra-norozzadeh/Kaggle%20House%20Prices%20Using%20MLP/runs/26uwvn4y</a><br/>
#                 Run data is saved locally in <code>/content/wandb/run-20210904_231002-26uwvn4y</code><br/><br/>
# <h1>Run(26uwvn4y)</h1><iframe src="https://wandb.ai/zahra-norozzadeh/Kaggle%20House%20Prices%20Using%20MLP/runs/26uwvn4y" style="border:none;width:100%;height:400px"></iframe>

# %%
train_data = pd.read_csv('train.csv')
train_data.head()
# Out:
#    Id  MSSubClass MSZoning  ...  SaleType  SaleCondition SalePrice
# 0   1          60       RL  ...        WD         Normal    208500
# 1   2          20       RL  ...        WD         Normal    181500
# 2   3          60       RL  ...        WD         Normal    223500
# 3   4          70       RL  ...        WD        Abnorml    140000
# 4   5          60       RL  ...        WD         Normal    250000
#
# [5 rows x 81 columns]

# %%
train_data = train_data.replace(['A','FV', 'C (all)', 'I', 'RH', 'RL', 'RP', 'RM'],[0,1,2,3,4,5,6,7])
train_data = train_data.replace(['Pave','Grvl'],[0,1])
train_data = train_data.replace(['Lvl','Bnk', 'HLS', 'Low'],[0,1,2,3])
train_data = train_data.replace(['AllPub','NoSewr', 'NoSeWa', 'ELO'],[0,1,2,3])
train_data = train_data.replace(['Gtl','Mod', 'Sev'],[0,1,2])
train_data = train_data.replace(['Artery','Feedr', 'Norm', 'RRNn', 'RRAn', 'PosN', 'PosA', 'RRNe', 'RRAe'],[0,1,2,3,4,5,6,7,8])
train_data = train_data.replace(['1Fam','2fmCon', 'Duplex', 'TwnhsE', 'Twnhs'],[0,1,2,3,4])
train_data = train_data.replace(['BrkTil','CBlock', 'PConc', 'Slab', 'Stone', 'Wood'],[0,1,2,3,4,5])
train_data = train_data.replace(['2Types','Attchd', 'Basment', 'BuiltIn', 'CarPort', 'Detchd'],[0,1,2,3,4,5])
train_data = train_data.fillna(0)

# %%
train_data
# Out:
#         Id  MSSubClass  MSZoning  ...  SaleType  SaleCondition  SalePrice
# 0        1          60         5  ...        WD         Normal     208500
# 1        2          20         5  ...        WD         Normal     181500
# 2        3          60         5  ...        WD         Normal     223500
# 3        4          70         5  ...        WD        Abnorml     140000
# 4        5          60         5  ...        WD         Normal     250000
# ...    ...         ...       ...  ...       ...            ...        ...
# 1455  1456          60         5  ...        WD         Normal     175000
# 1456  1457          20         5  ...        WD         Normal     210000
# 1457  1458          70         5  ...        WD         Normal     266500
# 1458  1459          20         5  ...        WD         Normal     142125
# 1459  1460          20         5  ...        WD         Normal     147500
#
# [1460 rows x 81 columns]

# %%
target_data= train_data[['SalePrice']]
data = train_data.drop(columns=['Id', 'SalePrice'])

# %%
data_train = data[['OverallQual','LandSlope','Condition1','Condition2','BldgType','OverallCond','Foundation','Utilities','GarageType','LotArea','KitchenAbvGr','ScreenPorch','EnclosedPorch','LandContour','FullBath','HalfBath','BsmtFinSF1','GrLivArea','Fireplaces','TotalBsmtSF','ScreenPorch','WoodDeckSF','Street', 'Alley', 'MSZoning','1stFlrSF','YearRemodAdd','LotFrontage','YearBuilt','EnclosedPorch','GarageArea','GarageCars','OpenPorchSF','MSSubClass','TotRmsAbvGrd']]

# %%
data_train1 = data[['OverallQual','LotArea','MiscVal','KitchenAbvGr','ScreenPorch','EnclosedPorch','LandContour','2ndFlrSF','FullBath','HalfBath','BsmtFinSF1','PoolArea','BsmtFinSF2', 'MasVnrArea', 'BsmtUnfSF', 'LowQualFinSF','GrLivArea','Fireplaces','TotalBsmtSF','3SsnPorch','ScreenPorch','WoodDeckSF','Street', 'Alley', 'MSZoning','1stFlrSF','YearRemodAdd','LotFrontage','YearBuilt','EnclosedPorch','GarageArea','GarageCars','OpenPorchSF','MSSubClass','TotalBsmtSF']]

# %%
data_train2 = data[['OverallQual','Foundation','GarageType','LotArea','ScreenPorch','EnclosedPorch','FullBath','HalfBath','BsmtFinSF1','GrLivArea','Fireplaces','TotalBsmtSF','ScreenPorch','WoodDeckSF', 'Alley', 'MSZoning','1stFlrSF','YearRemodAdd','LotFrontage','YearBuilt','EnclosedPorch','GarageArea','GarageCars','OpenPorchSF','TotRmsAbvGrd']]

# %%
data_train3 = data[['OverallQual','Foundation','GarageType','LotArea','ScreenPorch','EnclosedPorch','FullBath','BsmtFinSF1','GrLivArea','Fireplaces','TotalBsmtSF','ScreenPorch','WoodDeckSF','1stFlrSF','YearRemodAdd','YearBuilt','EnclosedPorch','GarageArea','GarageCars','TotRmsAbvGrd']]

# %%
X_train, X_val, y_train, y_val = train_test_split(data_train3, target_data, test_size=0.2, random_state=42)

# %%
X_train = np.array(X_train)
y_train = np.array(y_train)
X_val = np.array(X_val)
y_val = np.array(y_val)

# %%
model = tf.keras.models.Sequential([
    tf.keras.layers.Dense(128, activation='relu'),
    tf.keras.layers.Dense(64, activation='relu'),
    tf.keras.layers.Dense(32, activation='relu'),
    tf.keras.layers.Dense(16, activation='relu'),
    tf.keras.layers.Dense(1, activation='relu'),
])

# %%
model.compile(optimizer=tf.keras.optimizers.RMSprop(learning_rate=0.001),
              loss=tf.keras.losses.mean_squared_logarithmic_error)

# %%
config = wandb.config
config.learning_rate = 0.001

# %%
output = []

# %%
output = model.fit(X_train, y_train, validation_data=(X_val, y_val),callbacks=[WandbCallback()], epochs = 100)
# Out:
# Epoch 1/100
# 37/37 [==============================] - 1s 8ms/step - loss: 15.0052 - val_loss: 5.5468
# Epoch 2/100
# 37/37 [==============================] - 0s 2ms/step - loss: 3.1212 - val_loss: 1.3561
# Epoch 3/100
# 37/37 [==============================] - 0s 3ms/step - loss: 0.6142 - val_loss: 0.2087
# Epoch 4/100
# 37/37 [==============================] - 0s 3ms/step - loss: 0.1352 - val_loss: 0.1349
# Epoch 5/100
# 37/37 [==============================] - 0s 2ms/step - loss: 0.1048 - val_loss: 0.1048
# Epoch 6/100
# 37/37 [==============================] - 0s 3ms/step - loss: 0.0836 - val_loss: 0.0953
# Epoch 7/100
# 37/37 [==============================] - 0s 2ms/step - loss: 0.0707 - val_loss: 0.0750
# Epoch 8/100
# 37/37 [==============================] - 0s 3ms/step - loss: 0.0642 - val_loss: 0.0745
# Epoch 9/100
# 37/37 [==============================] - 0s 3ms/step - loss: 0.0603 - val_loss: 0.0621
# Epoch 10/100
# 37/37 [==============================] - 0s 2ms/step - loss: 0.0568 - val_loss: 0.0586
# Epoch 11/100
# 37/37 [==============================] - 0s 2ms/step - loss: 0.0537 - val_loss: 0.0552
# Epoch 12/100
# 37/37 [==============================] - 0s 3ms/step - loss: 0.0504 - val_loss: 0.0614
# Epoch 13/100
# 37/37 [==============================] - 0s 3ms/step - loss: 0.0496 - val_loss: 0.0565
# Epoch 14/100
# 37/37 [==============================] - 0s 2ms/step - loss: 0.0471 - val_loss: 0.0489
# Epoch 15/100
# 37/37 [==============================] - 0s 3ms/step - loss: 0.0476 - val_loss: 0.0590
# Epoch 16/100
# 37/37 [==============================] - 0s 3ms/step - loss: 0.0473 - val_loss: 0.0491
# Epoch 17/100
# 37/37 [==============================] - 0s 3ms/step - loss: 0.0458 - val_loss: 0.0480
# Epoch 18/100
# 37/37 [==============================] - 0s 3ms/step - loss: 0.0457 - val_loss: 0.0507
# Epoch 19/100
# 37/37 [==============================] - 0s 2ms/step - loss: 0.0452 - val_loss: 0.0470
# Epoch 20/100
# 37/37 [==============================] - 0s 3ms/step - loss: 0.0461 - val_loss: 0.0500
# Epoch 21/100
# 37/37 [==============================] - 0s 3ms/step - loss: 0.0458 - val_loss: 0.0503
# Epoch 22/100
# 37/37 [==============================] - 0s 3ms/step - loss: 0.0452 - val_loss: 0.0473
# Epoch 23/100
# 37/37 [==============================] - 0s 2ms/step - loss: 0.0446 - val_loss: 0.0468
# Epoch 24/100
# 37/37 [==============================] - 0s 3ms/step - loss: 0.0453 - val_loss: 0.0689
# Epoch 25/100
# 37/37 [==============================] - 0s 3ms/step - loss: 0.0452 - val_loss: 0.0504
# Epoch 26/100
# 37/37 [==============================] - 0s 3ms/step - loss: 0.0448 - val_loss: 0.0465
# Epoch 27/100
# 37/37 [==============================] - 0s 3ms/step - loss: 0.0447 - val_loss: 0.0468
# Epoch 28/100
# 37/37 [==============================] - 0s 3ms/step - loss: 0.0448 - val_loss: 0.0543
# Epoch 29/100
# 37/37 [==============================] - 0s 2ms/step - loss: 0.0445 - val_loss: 0.0485
# Epoch 30/100
# 37/37 [==============================] - 0s 3ms/step - loss: 0.0447 - val_loss: 0.0464
# Epoch 31/100
# 37/37 [==============================] - 0s 3ms/step - loss: 0.0448 - val_loss: 0.0485
# Epoch 32/100
# 37/37 [==============================] - 0s 3ms/step - loss: 0.0446 - val_loss: 0.0492
# Epoch 33/100
# 37/37 [==============================] - 0s 3ms/step - loss: 0.0443 - val_loss: 0.0462
# Epoch 34/100
# 37/37 [==============================] - 0s 3ms/step - loss: 0.0443 - val_loss: 0.0474
# Epoch 35/100
# 37/37 [==============================] - 0s 3ms/step - loss: 0.0434 - val_loss: 0.0489
# Epoch 36/100
# 37/37 [==============================] - 0s 3ms/step - loss: 0.0443 - val_loss: 0.0460
# Epoch 37/100
# 37/37 [==============================] - 0s 2ms/step - loss: 0.0444 - val_loss: 0.0475
# Epoch 38/100
# 37/37 [==============================] - 0s 3ms/step - loss: 0.0444 - val_loss: 0.0619
# Epoch 39/100
# 37/37 [==============================] - 0s 3ms/step - loss: 0.0434 - val_loss: 0.0464
# Epoch 40/100
# 37/37 [==============================] - 0s 3ms/step - loss: 0.0445 - val_loss: 0.0460
# Epoch 41/100
# 37/37 [==============================] - 0s 3ms/step - loss: 0.0435 - val_loss: 0.0491
# Epoch 42/100
# 37/37 [==============================] - 0s 3ms/step - loss: 0.0432 - val_loss: 0.0464
# Epoch 43/100
# 37/37 [==============================] - 0s 3ms/step - loss: 0.0435 - val_loss: 0.0481
# Epoch 44/100
# 37/37 [==============================] - 0s 3ms/step - loss: 0.0437 - val_loss: 0.0458
# Epoch 45/100
# 37/37 [==============================] - 0s 3ms/step - loss: 0.0431 - val_loss: 0.0459
# Epoch 46/100
# 37/37 [==============================] - 0s 3ms/step - loss: 0.0437 - val_loss: 0.0501
# Epoch 47/100
# 37/37 [==============================] - 0s 2ms/step - loss: 0.0428 - val_loss: 0.0495
# Epoch 48/100
# 37/37 [==============================] - 0s 3ms/step - loss: 0.0433 - val_loss: 0.0454
# Epoch 49/100
# 37/37 [==============================] - 0s 3ms/step - loss: 0.0427 - val_loss: 0.0470
# Epoch 50/100
# 37/37 [==============================] - 0s 3ms/step - loss: 0.0426 - val_loss: 0.0466
# Epoch 51/100
# 37/37 [==============================] - 0s 3ms/step - loss: 0.0430 - val_loss: 0.0513
# Epoch 52/100
# 37/37 [==============================] - 0s 3ms/step - loss: 0.0422 - val_loss: 0.0453
# Epoch 53/100
# 37/37 [==============================] - 0s 3ms/step - loss: 0.0429 - val_loss: 0.0476
# Epoch 54/100
# 37/37 [==============================] - 0s 3ms/step - loss: 0.0424 - val_loss: 0.0456
# Epoch 55/100
# 37/37 [==============================] - 0s 3ms/step - loss: 0.0419 - val_loss: 0.0464
# Epoch 56/100
# 37/37 [==============================] - 0s 3ms/step - loss: 0.0429 - val_loss: 0.0494
# Epoch 57/100
# 37/37 [==============================] - 0s 3ms/step - loss: 0.0416 - val_loss: 0.0477
# Epoch 58/100
# 37/37 [==============================] - 0s 3ms/step - loss: 0.0418 - val_loss: 0.0475
# Epoch 59/100
# 37/37 [==============================] - 0s 2ms/step - loss: 0.0424 - val_loss: 0.0491
# Epoch 60/100
# 37/37 [==============================] - 0s 3ms/step - loss: 0.0419 - val_loss: 0.0480
# Epoch 61/100
# 37/37 [==============================] - 0s 3ms/step - loss: 0.0415 - val_loss: 0.0445
# Epoch 62/100
# 37/37 [==============================] - 0s 3ms/step - loss: 0.0415 - val_loss: 0.0496
# Epoch 63/100
# 37/37 [==============================] - 0s 3ms/step - loss: 0.0418 - val_loss: 0.0485
# Epoch 64/100
# 37/37 [==============================] - 0s 3ms/step - loss: 0.0417 - val_loss: 0.0441
# Epoch 65/100
# 37/37 [==============================] - 0s 3ms/step - loss: 0.0413 - val_loss: 0.0504
# Epoch 66/100
# 37/37 [==============================] - 0s 3ms/step - loss: 0.0418 - val_loss: 0.0530
# Epoch 67/100
# 37/37 [==============================] - 0s 3ms/step - loss: 0.0410 - val_loss: 0.0443
# Epoch 68/100
# 37/37 [==============================] - 0s 2ms/step - loss: 0.0416 - val_loss: 0.0454
# Epoch 69/100
# 37/37 [==============================] - 0s 2ms/step - loss: 0.0407 - val_loss: 0.0444
# Epoch 70/100
# 37/37 [==============================] - 0s 3ms/step - loss: 0.0406 - val_loss: 0.0548
# Epoch 71/100
# 37/37 [==============================] - 0s 3ms/step - loss: 0.0408 - val_loss: 0.0438
# Epoch 72/100
# 37/37 [==============================] - 0s 3ms/step - loss: 0.0414 - val_loss: 0.0442
# Epoch 73/100
# 37/37 [==============================] - 0s 2ms/step - loss: 0.0407 - val_loss: 0.0438
# Epoch 74/100
# 37/37 [==============================] - 0s 3ms/step - loss: 0.0408 - val_loss: 0.0471
# Epoch 75/100
# 37/37 [==============================] - 0s 2ms/step - loss: 0.0400 - val_loss: 0.0472
# Epoch 76/100
# 37/37 [==============================] - 0s 3ms/step - loss: 0.0405 - val_loss: 0.0433
# Epoch 77/100
# 37/37 [==============================] - 0s 3ms/step - loss: 0.0399 - val_loss: 0.0440
# Epoch 78/100
# 37/37 [==============================] - 0s 3ms/step - loss: 0.0404 - val_loss: 0.0440
# Epoch 79/100
# 37/37 [==============================] - 0s 3ms/step - loss: 0.0402 - val_loss: 0.0434
# Epoch 80/100
# 37/37 [==============================] - 0s 3ms/step - loss: 0.0407 - val_loss: 0.0448
# Epoch 81/100
# 37/37 [==============================] - 0s 3ms/step - loss: 0.0398 - val_loss: 0.0433
# Epoch 82/100
# 37/37 [==============================] - 0s 3ms/step - loss: 0.0403 - val_loss: 0.0430
# Epoch 83/100
# 37/37 [==============================] - 0s 3ms/step - loss: 0.0397 - val_loss: 0.0467
# Epoch 84/100
# 37/37 [==============================] - 0s 3ms/step - loss: 0.0398 - val_loss: 0.0429
# Epoch 85/100
# 37/37 [==============================] - 0s 3ms/step - loss: 0.0398 - val_loss: 0.0426
# Epoch 86/100
# 37/37 [==============================] - 0s 3ms/step - loss: 0.0397 - val_loss: 0.0423
# Epoch 87/100
# 37/37 [==============================] - 0s 3ms/step - loss: 0.0404 - val_loss: 0.0438
# Epoch 88/100
# 37/37 [==============================] - 0s 3ms/step - loss: 0.0399 - val_loss: 0.0443
# Epoch 89/100
# 37/37 [==============================] - 0s 3ms/step - loss: 0.0402 - val_loss: 0.0427
# Epoch 90/100
# 37/37 [==============================] - 0s 3ms/step - loss: 0.0391 - val_loss: 0.0424
# Epoch 91/100
# 37/37 [==============================] - 0s 3ms/step - loss: 0.0397 - val_loss: 0.0447
# Epoch 92/100
# 37/37 [==============================] - 0s 3ms/step - loss: 0.0394 - val_loss: 0.0438
# Epoch 93/100
# 37/37 [==============================] - 0s 3ms/step - loss: 0.0391 - val_loss: 0.0595
# Epoch 94/100
# 37/37 [==============================] - 0s 3ms/step - loss: 0.0393 - val_loss: 0.0488
# Epoch 95/100
# 37/37 [==============================] - 0s 3ms/step - loss: 0.0393 - val_loss: 0.0499
# Epoch 96/100
# 37/37 [==============================] - 0s 2ms/step - loss: 0.0394 - val_loss: 0.0437
# Epoch 97/100
# 37/37 [==============================] - 0s 3ms/step - loss: 0.0390 - val_loss: 0.0515
# Epoch 98/100
# 37/37 [==============================] - 0s 3ms/step - loss: 0.0389 - val_loss: 0.0425
# Epoch 99/100
# 37/37 [==============================] - 0s 2ms/step - loss: 0.0393 - val_loss: 0.0464
# Epoch 100/100
# 37/37 [==============================] - 0s 2ms/step - loss: 0.0389 - val_loss: 0.0426

# %%
test_data = pd.read_csv('test.csv')

# %%
test_data = test_data.replace(['A','FV', 'C (all)', 'I', 'RH', 'RL', 'RP', 'RM'],[0,1,2,3,4,5,6,7])
test_data = test_data.replace(['Pave','Grvl'],[0,1])
test_data = test_data.replace(['Lvl','Bnk', 'HLS', 'Low'],[0,1,2,3])
test_data = test_data.replace(['AllPub','NoSewr', 'NoSeWa', 'ELO'],[0,1,2,3])
test_data = test_data.replace(['Gtl','Mod', 'Sev'],[0,1,2])
test_data = test_data.replace(['Artery','Feedr', 'Norm', 'RRNn', 'RRAn', 'PosN', 'PosA', 'RRNe', 'RRAe'],[0,1,2,3,4,5,6,7,8])
test_data = test_data.replace(['1Fam','2fmCon', 'Duplex', 'TwnhsE', 'Twnhs'],[0,1,2,3,4])
test_data = test_data.replace(['BrkTil','CBlock', 'PConc', 'Slab', 'Stone', 'Wood'],[0,1,2,3,4,5])
test_data = test_data.replace(['2Types','Attchd', 'Basment', 'BuiltIn', 'CarPort', 'Detchd'],[0,1,2,3,4,5])
test_data = test_data.fillna(0)

# %%
targer =  pd.read_csv('sample_submission.csv')
y_test = targer[['SalePrice']]

# %%
y_test = np.array(y_test)

# %%
x_test = test_data[['OverallQual','LandSlope','Condition1','Condition2','BldgType','OverallCond','Foundation','Utilities','GarageType','LotArea','KitchenAbvGr','ScreenPorch','EnclosedPorch','LandContour','FullBath','HalfBath','BsmtFinSF1','GrLivArea','Fireplaces','TotalBsmtSF','ScreenPorch','WoodDeckSF','Street', 'Alley', 'MSZoning','1stFlrSF','YearRemodAdd','LotFrontage','YearBuilt','EnclosedPorch','GarageArea','GarageCars','OpenPorchSF','MSSubClass','TotRmsAbvGrd']]

# %%
x_test2 = test_data[['OverallQual','Foundation','GarageType','LotArea','ScreenPorch','EnclosedPorch','FullBath','HalfBath','BsmtFinSF1','GrLivArea','Fireplaces','TotalBsmtSF','ScreenPorch','WoodDeckSF', 'Alley', 'MSZoning','1stFlrSF','YearRemodAdd','LotFrontage','YearBuilt','EnclosedPorch','GarageArea','GarageCars','OpenPorchSF','TotRmsAbvGrd']]

# %%
x_test3 = test_data[['OverallQual','Foundation','GarageType','LotArea','ScreenPorch','EnclosedPorch','FullBath','BsmtFinSF1','GrLivArea','Fireplaces','TotalBsmtSF','ScreenPorch','WoodDeckSF','1stFlrSF','YearRemodAdd','YearBuilt','EnclosedPorch','GarageArea','GarageCars','TotRmsAbvGrd']]

# %%
x_test = np.array(x_test3)

# %%
model.evaluate(x_test, y_test)
# Out:
# 46/46 [==============================] - 0s 2ms/step - loss: 0.1101
# 0.11011993885040283

# %%
target_data = train_data[['SalePrice']]
target_data = np.array(target_data).T
R = []
for column in data_train.columns:
    a = np.array(data_train[column]).T
    r = np.corrcoef(a, target_data)
    R.append(r[0,1])

# %%
print(R)
# Out:
# [0.7909816005838044, 0.05115224817946654, 0.08383810316349818, 0.0574897449631512, -0.11261070204133265, -0.07785589404867803, 0.38247899119010176, -0.014314296147248806, -0.2634685962463248, 0.2638433538714056, -0.13590737084214122, 1.0, 1.0, 0.0730415748938043, 0.5606637627484449, 0.2841076755947831, 0.3864198062421532, 0.7086244776126523, 0.46692883675152724, 0.6135805515591956, 1.0, 0.3244134445681294, -0.041035535500049486, -0.1391954581722088, -0.20916335158272992, 0.6058521846919147, 0.5071009671113865, 0.2096239447994838, 0.5228973328794969, 1.0, 0.6234314389183618, 0.6404091972583529, 0.3158562271160555, -0.08428413512659531, 0.5337231555820282]

# %%
dataanalyse = pd.DataFrame(data_train.columns, R)

# %%
dataanalyse
# Out:
#                        0
#  0.790982    OverallQual
#  0.051152      LandSlope
#  0.083838     Condition1
#  0.057490     Condition2
# -0.112611       BldgType
# -0.077856    OverallCond
#  0.382479     Foundation
# -0.014314      Utilities
# -0.263469     GarageType
#  0.263843        LotArea
# -0.135907   KitchenAbvGr
#  1.000000    ScreenPorch
#  1.000000  EnclosedPorch
#  0.073042    LandContour
#  0.560664       FullBath
#  0.284108       HalfBath
#  0.386420     BsmtFinSF1
#  0.708624      GrLivArea
#  0.466929     Fireplaces
#  0.613581    TotalBsmtSF
#  1.000000    ScreenPorch
#  0.324413     WoodDeckSF
# -0.041036         Street
# -0.139195          Alley
# -0.209163       MSZoning
#  0.605852       1stFlrSF
#  0.507101   YearRemodAdd
#  0.209624    LotFrontage
#  0.522897      YearBuilt
#  1.000000  EnclosedPorch
#  0.623431     GarageArea
#  0.640409     GarageCars
#  0.315856    OpenPorchSF
# -0.084284     MSSubClass
#  0.533723   TotRmsAbvGrd

# %%
data_train2 = data[['OverallQual','Foundation','GarageType','LotArea','ScreenPorch','EnclosedPorch','FullBath','HalfBath','BsmtFinSF1','GrLivArea','Fireplaces','TotalBsmtSF','ScreenPorch','WoodDeckSF', 'Alley', 'MSZoning','1stFlrSF','YearRemodAdd','LotFrontage','YearBuilt','EnclosedPorch','GarageArea','GarageCars','OpenPorchSF','TotRmsAbvGrd']]

# %%
data_train3 = data[['OverallQual','Foundation','GarageType','LotArea','ScreenPorch','EnclosedPorch','FullBath','BsmtFinSF1','GrLivArea','Fireplaces','TotalBsmtSF','ScreenPorch','WoodDeckSF','1stFlrSF','YearRemodAdd','YearBuilt','EnclosedPorch','GarageArea','GarageCars','TotRmsAbvGrd']]

# %%
data_train2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 25 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   OverallQual    1460 non-null   int64
#  1   Foundation     1460 non-null   int64
#  2   GarageType     1460 non-null   float64
#  3   LotArea        1460 non-null   int64
#  4   ScreenPorch    1460 non-null   int64
#  5   EnclosedPorch  1460 non-null   int64
#  6   FullBath       1460 non-null   int64
#  7   HalfBath       1460 non-null   int64
#  8   BsmtFinSF1     1460 non-null   int64
#  9   GrLivArea      1460 non-null   int64
#  10  Fireplaces     1460 non-null   int64
#  11  TotalBsmtSF    1460 non-null   int64
#  12  ScreenPorch    1460 non-null   int64
#  13  WoodDeckSF     1460 non-null   int64
#  14  Alley          1460 non-null   float64
#  15  MSZoning       1460 non-null   int64
#  16  1stFlrSF       1460 non-null   int64
#  17  YearRemodAdd   1460 non-null   int64
#  18  LotFrontage    1460 non-null   float64
#  19  YearBuilt      1460 non-null   int64
#  20  EnclosedPorch  1460 non-null   int64
#  21  GarageArea     1460 non-null   int64
#  22  GarageCars     1460 non-null   int64
#  23  OpenPorchSF    1460 non-null   int64
#  24  TotRmsAbvGrd   1460 non-null   int64
# dtypes: float64(3), int64(22)
# memory usage: 285.3 KB
